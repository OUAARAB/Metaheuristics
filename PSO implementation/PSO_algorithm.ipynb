# %%
import numpy as np
import time

# Function to calculate Euclidean distance between two points
def euclidean_distance(point1, point2):
    return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# Function to calculate the total distance of a given tour
def calculate_total_distance(tour, coordinates):
    total_distance = 0
    for i in range(len(tour) - 1):
        # Calculate the Euclidean distance between consecutive cities in the tour
        total_distance += euclidean_distance(coordinates[tour[i]], coordinates[tour[i + 1]])
    # Add the distance from the last city back to the starting city
    total_distance += euclidean_distance(coordinates[tour[-1]], coordinates[tour[0]])  # Return to the starting city
    return total_distance

# Function to initialize particles
def initialize_particles(num_particles, num_cities):
    particles = []
    for _ in range(num_particles):
        # Create a particle with a random permutation of city indices
        particle = np.random.permutation(num_cities)
        particles.append({
            'position': particle,
            'velocity': np.zeros(num_cities),
            'pbest': None,
            'pbest_distance': float('inf')
        })
    return particles

# Main PSO function
def pso(coordinates, num_particles, num_iterations, limit):
    num_cities = len(coordinates)
    # Initialize particles
    particles = initialize_particles(num_particles, num_cities)
    gbest = {'position': None, 'gbest_distance': float('inf')}

    # Record the start time for execution time calculation
    start_time = time.time()

    # Set constants for the PSO algorithm
    inertia = 0.5
    cognitive_coefficient = 2.0
    social_coefficient = 2.0

    # PSO iterations
    for iteration in range(num_iterations):
        # Iterate through each particle
        for i in range(num_particles):
            particle = particles[i]

            # Calculate fitness function (total distance of the tour)
            particle_distance = calculate_total_distance(particle['position'], coordinates)

            # Update personal best (pbest) and global best (gbest)
            if particle_distance < particle['pbest_distance']:
                particle['pbest'] = np.copy(particle['position'])
                particle['pbest_distance'] = particle_distance

            if particle_distance < gbest['gbest_distance']:
                gbest['position'] = np.copy(particle['position'])
                gbest['gbest_distance'] = particle_distance

            # Update velocity and position using PSO equations
            r1 = np.random.rand(num_cities)
            r2 = np.random.rand(num_cities)

            particle['velocity'] = (inertia * particle['velocity'] +
                                    cognitive_coefficient * r1 * (particle['pbest'] - particle['position']) +
                                    social_coefficient * r2 * (gbest['position'] - particle['position']))

            # Update position with modulo operation
            new_position = (np.round(particle['position'] + particle['velocity']) % num_cities).astype(int)
            particle['position'] = new_position

            # Apply position limit
            particle['position'][particle['position'] > limit] = limit

        # Print the best distance for the current iteration
        print(f"Iteration {iteration + 1}/{num_iterations} - Best Distance: {gbest['gbest_distance']}")

    # Record the end time for execution time calculation
    end_time = time.time()
    execution_time = end_time - start_time

    return gbest['position'], gbest['gbest_distance'], execution_time

# Load city coordinates from a local file
def load_coordinates_from_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Find the index where NODE_COORD_SECTION starts
    node_coord_section_index = lines.index("NODE_COORD_SECTION\n") + 1

    # Extract city coordinates
    coordinates = []
    for line in lines[node_coord_section_index:]:
        if line.strip() == "EOF":
            break
        parts = line.split()
        coordinates.append([float(parts[1]), float(parts[2])])

    return np.array(coordinates)

# Replace 'your_file_path.txt' with the path to your dataset file
file_path = "C:/Users/Hicham/Downloads/berlin52.tsp"
ch130_coordinates = load_coordinates_from_file(file_path)

# Parameters for PSO
num_particles = 300
num_iterations = 300
limit = 700.0  # Assuming the limit mentioned in the algorithm is for position limit

# Run PSO
best_solution, best_distance, execution_time = pso(ch130_coordinates, num_particles, num_iterations, limit)

# Display results
print("\nResults:")
print(f"Best Distance: {best_distance}")
print(f"Best Solution (Tour): {best_solution}")
print(f"Execution Time: {execution_time} seconds")
# Out:
# Iteration 1/300 - Best Distance: 25895.414442131932
# Iteration 2/300 - Best Distance: 18991.626535934196
# Iteration 3/300 - Best Distance: 18991.626535934196
# Iteration 4/300 - Best Distance: 18991.626535934196
# Iteration 5/300 - Best Distance: 17111.110149873606
# Iteration 6/300 - Best Distance: 17111.110149873606
# Iteration 7/300 - Best Distance: 17111.110149873606
# Iteration 8/300 - Best Distance: 17111.110149873606
# Iteration 9/300 - Best Distance: 17111.110149873606
# Iteration 10/300 - Best Distance: 17111.110149873606
# Iteration 11/300 - Best Distance: 17111.110149873606
# Iteration 12/300 - Best Distance: 17111.110149873606
# Iteration 13/300 - Best Distance: 17111.110149873606
# Iteration 14/300 - Best Distance: 17111.110149873606
# Iteration 15/300 - Best Distance: 17111.110149873606
# Iteration 16/300 - Best Distance: 17111.110149873606
# Iteration 17/300 - Best Distance: 17111.110149873606
# Iteration 18/300 - Best Distance: 16195.146883545565
# Iteration 19/300 - Best Distance: 16195.146883545565
# Iteration 20/300 - Best Distance: 16195.146883545565
# Iteration 21/300 - Best Distance: 16195.146883545565
# Iteration 22/300 - Best Distance: 16195.146883545565
# Iteration 23/300 - Best Distance: 16195.146883545565
# Iteration 24/300 - Best Distance: 16195.146883545565
# Iteration 25/300 - Best Distance: 16195.146883545565
# Iteration 26/300 - Best Distance: 16195.146883545565
# Iteration 27/300 - Best Distance: 16195.146883545565
# Iteration 28/300 - Best Distance: 16195.146883545565
# Iteration 29/300 - Best Distance: 16195.146883545565
# Iteration 30/300 - Best Distance: 16195.146883545565
# Iteration 31/300 - Best Distance: 16195.146883545565
# Iteration 32/300 - Best Distance: 16195.146883545565
# Iteration 33/300 - Best Distance: 16195.146883545565
# Iteration 34/300 - Best Distance: 16195.146883545565
# Iteration 35/300 - Best Distance: 16195.146883545565
# Iteration 36/300 - Best Distance: 14736.806879775955
# Iteration 37/300 - Best Distance: 14736.806879775955
# Iteration 38/300 - Best Distance: 14736.806879775955
# Iteration 39/300 - Best Distance: 14736.806879775955
# Iteration 40/300 - Best Distance: 14736.806879775955
# Iteration 41/300 - Best Distance: 14736.806879775955
# Iteration 42/300 - Best Distance: 14736.806879775955
# Iteration 43/300 - Best Distance: 14736.806879775955
# Iteration 44/300 - Best Distance: 14736.806879775955
# Iteration 45/300 - Best Distance: 14736.806879775955
# Iteration 46/300 - Best Distance: 14736.806879775955
# Iteration 47/300 - Best Distance: 14736.806879775955
# Iteration 48/300 - Best Distance: 14736.806879775955
# Iteration 49/300 - Best Distance: 14736.806879775955
# Iteration 50/300 - Best Distance: 14736.806879775955
# Iteration 51/300 - Best Distance: 14736.806879775955
# Iteration 52/300 - Best Distance: 14736.806879775955
# Iteration 53/300 - Best Distance: 14736.806879775955
# Iteration 54/300 - Best Distance: 14736.806879775955
# Iteration 55/300 - Best Distance: 14736.806879775955
# Iteration 56/300 - Best Distance: 14736.806879775955
# Iteration 57/300 - Best Distance: 14736.806879775955
# Iteration 58/300 - Best Distance: 14736.806879775955
# Iteration 59/300 - Best Distance: 14736.806879775955
# Iteration 60/300 - Best Distance: 14736.806879775955
# Iteration 61/300 - Best Distance: 14736.806879775955
# Iteration 62/300 - Best Distance: 14736.806879775955
# Iteration 63/300 - Best Distance: 14736.806879775955
# Iteration 64/300 - Best Distance: 14736.806879775955
# Iteration 65/300 - Best Distance: 14736.806879775955
# Iteration 66/300 - Best Distance: 14736.806879775955
# Iteration 67/300 - Best Distance: 14736.806879775955
# Iteration 68/300 - Best Distance: 14736.806879775955
# Iteration 69/300 - Best Distance: 14736.806879775955
# Iteration 70/300 - Best Distance: 14736.806879775955
# Iteration 71/300 - Best Distance: 14710.243625919993
# Iteration 72/300 - Best Distance: 14710.243625919993
# Iteration 73/300 - Best Distance: 14710.243625919993
# Iteration 74/300 - Best Distance: 13650.088120998636
# Iteration 75/300 - Best Distance: 13650.088120998636
# Iteration 76/300 - Best Distance: 13650.088120998636
# Iteration 77/300 - Best Distance: 13650.088120998636
# Iteration 78/300 - Best Distance: 13650.088120998636
# Iteration 79/300 - Best Distance: 13650.088120998636
# Iteration 80/300 - Best Distance: 12754.15160918792
# Iteration 81/300 - Best Distance: 12754.15160918792
# Iteration 82/300 - Best Distance: 12687.85010847828
# Iteration 83/300 - Best Distance: 12687.85010847828
# Iteration 84/300 - Best Distance: 12687.85010847828
# Iteration 85/300 - Best Distance: 12687.85010847828
# Iteration 86/300 - Best Distance: 12687.85010847828
# Iteration 87/300 - Best Distance: 12687.85010847828
# Iteration 88/300 - Best Distance: 12687.85010847828
# Iteration 89/300 - Best Distance: 12364.827936444992
# Iteration 90/300 - Best Distance: 12364.827936444992
# Iteration 91/300 - Best Distance: 11740.528870308684
# Iteration 92/300 - Best Distance: 11740.528870308684
# Iteration 93/300 - Best Distance: 11740.528870308684
# Iteration 94/300 - Best Distance: 11740.528870308684
# Iteration 95/300 - Best Distance: 11740.528870308684
# Iteration 96/300 - Best Distance: 11740.528870308684
# Iteration 97/300 - Best Distance: 11740.528870308684
# Iteration 98/300 - Best Distance: 11740.528870308684
# Iteration 99/300 - Best Distance: 11740.528870308684
# Iteration 100/300 - Best Distance: 11740.528870308684
# Iteration 101/300 - Best Distance: 11444.897178407235
# Iteration 102/300 - Best Distance: 11444.897178407235
# Iteration 103/300 - Best Distance: 11444.897178407235
# Iteration 104/300 - Best Distance: 11444.897178407235
# Iteration 105/300 - Best Distance: 11444.897178407235
# Iteration 106/300 - Best Distance: 11444.897178407235
# Iteration 107/300 - Best Distance: 11444.897178407235
# Iteration 108/300 - Best Distance: 11444.897178407235
# Iteration 109/300 - Best Distance: 11444.897178407235
# Iteration 110/300 - Best Distance: 11444.897178407235
# Iteration 111/300 - Best Distance: 11444.897178407235
# Iteration 112/300 - Best Distance: 11444.897178407235
# Iteration 113/300 - Best Distance: 11444.897178407235
# Iteration 114/300 - Best Distance: 11444.897178407235
# Iteration 115/300 - Best Distance: 11444.897178407235
# Iteration 116/300 - Best Distance: 11444.897178407235
# Iteration 117/300 - Best Distance: 11444.897178407235
# Iteration 118/300 - Best Distance: 11444.897178407235
# Iteration 119/300 - Best Distance: 11444.897178407235
# Iteration 120/300 - Best Distance: 11444.897178407235
# Iteration 121/300 - Best Distance: 11444.897178407235
# Iteration 122/300 - Best Distance: 11444.897178407235
# Iteration 123/300 - Best Distance: 11444.897178407235
# Iteration 124/300 - Best Distance: 11444.897178407235
# Iteration 125/300 - Best Distance: 11444.897178407235
# Iteration 126/300 - Best Distance: 11444.897178407235
# Iteration 127/300 - Best Distance: 11444.897178407235
# Iteration 128/300 - Best Distance: 11444.897178407235
# Iteration 129/300 - Best Distance: 11444.897178407235
# Iteration 130/300 - Best Distance: 11444.897178407235
# Iteration 131/300 - Best Distance: 11444.897178407235
# Iteration 132/300 - Best Distance: 11444.897178407235
# Iteration 133/300 - Best Distance: 11444.897178407235
# Iteration 134/300 - Best Distance: 11444.897178407235
# Iteration 135/300 - Best Distance: 11444.897178407235
# Iteration 136/300 - Best Distance: 11444.897178407235
# Iteration 137/300 - Best Distance: 11444.897178407235
# Iteration 138/300 - Best Distance: 11444.897178407235
# Iteration 139/300 - Best Distance: 11444.897178407235
# Iteration 140/300 - Best Distance: 11444.897178407235
# Iteration 141/300 - Best Distance: 11444.897178407235
# Iteration 142/300 - Best Distance: 11444.897178407235
# Iteration 143/300 - Best Distance: 11444.897178407235
# Iteration 144/300 - Best Distance: 11444.897178407235
# Iteration 145/300 - Best Distance: 11444.897178407235
# Iteration 146/300 - Best Distance: 11444.897178407235
# Iteration 147/300 - Best Distance: 11444.897178407235
# Iteration 148/300 - Best Distance: 11444.897178407235
# Iteration 149/300 - Best Distance: 11444.897178407235
# Iteration 150/300 - Best Distance: 11444.897178407235
# Iteration 151/300 - Best Distance: 11444.897178407235
# Iteration 152/300 - Best Distance: 11444.897178407235
# Iteration 153/300 - Best Distance: 11444.897178407235
# Iteration 154/300 - Best Distance: 11444.897178407235
# Iteration 155/300 - Best Distance: 11444.897178407235
# Iteration 156/300 - Best Distance: 11444.897178407235
# Iteration 157/300 - Best Distance: 11444.897178407235
# Iteration 158/300 - Best Distance: 11444.897178407235
# Iteration 159/300 - Best Distance: 11444.897178407235
# Iteration 160/300 - Best Distance: 11444.897178407235
# Iteration 161/300 - Best Distance: 11444.897178407235
# Iteration 162/300 - Best Distance: 11069.269110216663
# Iteration 163/300 - Best Distance: 11069.269110216663
# Iteration 164/300 - Best Distance: 11069.269110216663
# Iteration 165/300 - Best Distance: 11069.269110216663
# Iteration 166/300 - Best Distance: 11069.269110216663
# Iteration 167/300 - Best Distance: 11069.269110216663
# Iteration 168/300 - Best Distance: 11069.269110216663
# Iteration 169/300 - Best Distance: 11069.269110216663
# Iteration 170/300 - Best Distance: 11069.269110216663
# Iteration 171/300 - Best Distance: 11069.269110216663
# Iteration 172/300 - Best Distance: 11069.269110216663
# Iteration 173/300 - Best Distance: 11069.269110216663
# Iteration 174/300 - Best Distance: 11069.269110216663
# Iteration 175/300 - Best Distance: 11069.269110216663
# Iteration 176/300 - Best Distance: 11069.269110216663
# Iteration 177/300 - Best Distance: 11069.269110216663
# Iteration 178/300 - Best Distance: 11069.269110216663
# Iteration 179/300 - Best Distance: 11069.269110216663
# Iteration 180/300 - Best Distance: 11069.269110216663
# Iteration 181/300 - Best Distance: 11069.269110216663
# Iteration 182/300 - Best Distance: 11069.269110216663
# Iteration 183/300 - Best Distance: 11069.269110216663
# Iteration 184/300 - Best Distance: 11069.269110216663
# Iteration 185/300 - Best Distance: 11069.269110216663
# Iteration 186/300 - Best Distance: 11069.269110216663
# Iteration 187/300 - Best Distance: 11069.269110216663
# Iteration 188/300 - Best Distance: 11069.269110216663
# Iteration 189/300 - Best Distance: 11069.269110216663
# Iteration 190/300 - Best Distance: 11069.269110216663
# Iteration 191/300 - Best Distance: 11069.269110216663
# Iteration 192/300 - Best Distance: 11069.269110216663
# Iteration 193/300 - Best Distance: 11069.269110216663
# Iteration 194/300 - Best Distance: 11069.269110216663
# Iteration 195/300 - Best Distance: 11069.269110216663
# Iteration 196/300 - Best Distance: 11069.269110216663
# Iteration 197/300 - Best Distance: 11069.269110216663
# Iteration 198/300 - Best Distance: 11069.269110216663
# Iteration 199/300 - Best Distance: 11069.269110216663
# Iteration 200/300 - Best Distance: 11069.269110216663
# Iteration 201/300 - Best Distance: 11069.269110216663
# Iteration 202/300 - Best Distance: 11069.269110216663
# Iteration 203/300 - Best Distance: 11069.269110216663
# Iteration 204/300 - Best Distance: 11069.269110216663
# Iteration 205/300 - Best Distance: 11069.269110216663
# Iteration 206/300 - Best Distance: 11069.269110216663
# Iteration 207/300 - Best Distance: 11069.269110216663
# Iteration 208/300 - Best Distance: 11069.269110216663
# Iteration 209/300 - Best Distance: 11069.269110216663
# Iteration 210/300 - Best Distance: 11069.269110216663
# Iteration 211/300 - Best Distance: 11069.269110216663
# Iteration 212/300 - Best Distance: 11069.269110216663
# Iteration 213/300 - Best Distance: 11069.269110216663
# Iteration 214/300 - Best Distance: 11069.269110216663
# Iteration 215/300 - Best Distance: 11069.269110216663
# Iteration 216/300 - Best Distance: 11069.269110216663
# Iteration 217/300 - Best Distance: 11069.269110216663
# Iteration 218/300 - Best Distance: 11069.269110216663
# Iteration 219/300 - Best Distance: 11069.269110216663
# Iteration 220/300 - Best Distance: 11069.269110216663
# Iteration 221/300 - Best Distance: 11069.269110216663
# Iteration 222/300 - Best Distance: 11069.269110216663
# Iteration 223/300 - Best Distance: 11069.269110216663
# Iteration 224/300 - Best Distance: 11069.269110216663
# Iteration 225/300 - Best Distance: 11069.269110216663
# Iteration 226/300 - Best Distance: 11069.269110216663
# Iteration 227/300 - Best Distance: 11069.269110216663
# Iteration 228/300 - Best Distance: 11069.269110216663
# Iteration 229/300 - Best Distance: 11069.269110216663
# Iteration 230/300 - Best Distance: 11069.269110216663
# Iteration 231/300 - Best Distance: 11069.269110216663
# Iteration 232/300 - Best Distance: 11069.269110216663
# Iteration 233/300 - Best Distance: 11069.269110216663
# Iteration 234/300 - Best Distance: 11069.269110216663
# Iteration 235/300 - Best Distance: 11069.269110216663
# Iteration 236/300 - Best Distance: 11069.269110216663
# Iteration 237/300 - Best Distance: 11069.269110216663
# Iteration 238/300 - Best Distance: 11069.269110216663
# Iteration 239/300 - Best Distance: 11069.269110216663
# Iteration 240/300 - Best Distance: 11069.269110216663
# Iteration 241/300 - Best Distance: 11069.269110216663
# Iteration 242/300 - Best Distance: 11069.269110216663
# Iteration 243/300 - Best Distance: 11069.269110216663
# Iteration 244/300 - Best Distance: 11069.269110216663
# Iteration 245/300 - Best Distance: 11069.269110216663
# Iteration 246/300 - Best Distance: 11069.269110216663
# Iteration 247/300 - Best Distance: 11069.269110216663
# Iteration 248/300 - Best Distance: 11069.269110216663
# Iteration 249/300 - Best Distance: 11069.269110216663
# Iteration 250/300 - Best Distance: 11069.269110216663
# Iteration 251/300 - Best Distance: 11069.269110216663
# Iteration 252/300 - Best Distance: 11069.269110216663
# Iteration 253/300 - Best Distance: 11069.269110216663
# Iteration 254/300 - Best Distance: 10952.978843877283
# Iteration 255/300 - Best Distance: 10952.978843877283
# Iteration 256/300 - Best Distance: 10952.978843877283
# Iteration 257/300 - Best Distance: 10952.978843877283
# Iteration 258/300 - Best Distance: 10952.978843877283
# Iteration 259/300 - Best Distance: 10952.978843877283
# Iteration 260/300 - Best Distance: 10952.978843877283
# Iteration 261/300 - Best Distance: 10952.978843877283
# Iteration 262/300 - Best Distance: 10952.978843877283
# Iteration 263/300 - Best Distance: 10952.978843877283
# Iteration 264/300 - Best Distance: 10952.978843877283
# Iteration 265/300 - Best Distance: 10952.978843877283
# Iteration 266/300 - Best Distance: 10952.978843877283
# Iteration 267/300 - Best Distance: 10952.978843877283
# Iteration 268/300 - Best Distance: 10952.978843877283
# Iteration 269/300 - Best Distance: 10952.978843877283
# Iteration 270/300 - Best Distance: 10952.978843877283
# Iteration 271/300 - Best Distance: 10952.978843877283
# Iteration 272/300 - Best Distance: 10952.978843877283
# Iteration 273/300 - Best Distance: 10952.978843877283
# Iteration 274/300 - Best Distance: 10952.978843877283
# Iteration 275/300 - Best Distance: 10952.978843877283
# Iteration 276/300 - Best Distance: 10952.978843877283
# Iteration 277/300 - Best Distance: 10952.978843877283
# Iteration 278/300 - Best Distance: 10952.978843877283
# Iteration 279/300 - Best Distance: 10952.978843877283
# Iteration 280/300 - Best Distance: 10952.978843877283
# Iteration 281/300 - Best Distance: 10952.978843877283
# Iteration 282/300 - Best Distance: 10952.978843877283
# Iteration 283/300 - Best Distance: 10952.978843877283
# Iteration 284/300 - Best Distance: 10952.978843877283
# Iteration 285/300 - Best Distance: 10952.978843877283
# Iteration 286/300 - Best Distance: 10952.978843877283
# Iteration 287/300 - Best Distance: 10952.978843877283
# Iteration 288/300 - Best Distance: 10952.978843877283
# Iteration 289/300 - Best Distance: 10952.978843877283
# Iteration 290/300 - Best Distance: 10396.54721146836
# Iteration 291/300 - Best Distance: 10396.54721146836
# Iteration 292/300 - Best Distance: 10396.54721146836
# Iteration 293/300 - Best Distance: 10396.54721146836
# Iteration 294/300 - Best Distance: 10396.54721146836
# Iteration 295/300 - Best Distance: 10396.54721146836
# Iteration 296/300 - Best Distance: 10396.54721146836
# Iteration 297/300 - Best Distance: 10396.54721146836
# Iteration 298/300 - Best Distance: 10396.54721146836
# Iteration 299/300 - Best Distance: 10396.54721146836
# Iteration 300/300 - Best Distance: 10396.54721146836
#
# Results:
# Best Distance: 10396.54721146836
# Best Solution (Tour): [25 24 19 14 38 24 14 33 24 45 45  4 34 21 31 18 23 33 33 38 15 22 35  5
#  38 14 36 15 31 23 14 36 45 23 35 37 38 22 17 23 45 24 24 23 23 23 36 31
#  18 24 35 37]
# Execution Time: 32.9477436542511 seconds
